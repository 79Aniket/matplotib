# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# ### Matplotlib.

# %% [markdown]
# #### What is Matplotlib = Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python
# #### Why is it used = Matplotlib is used to visualize data for a variety of purposes. To visualize data for exploratory analysis
# #### Name five = Bar charts, Line plots, Scatter plots, Histograms, 3D plots

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# ### plot a scatter plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.title('Scatter Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

fig, axes = plt.subplots(2, 2)
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Line 1')
axes[0, 1].plot(x, y2)
axes[0, 1].set_title('Line 2')
axes[1, 0].plot(x, y3)
axes[1, 0].set_title('Line 3')
axes[1, 1].plot(x, y4)
axes[1, 1].set_title('Line 4')
plt.show()

# %% [markdown]
# #### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.xlabel("Company")
plt.ylabel("Profit")
plt.show()

# %%
plt.barh(company,profit) #horizontal bar plot.
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2])
plt.xlabel("x")
plt.ylabel("y")
plt.show()
